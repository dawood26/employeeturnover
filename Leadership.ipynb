# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#https://blog.softhints.com/pandas-display-all-columns-and-show-more-rows/
import numpy as np
df_surveymonkey = pd.read_csv ('survey-monkey2.csv',skiprows=0)
#df_finaldata=pd.read_csv ('final_data.csv')

# %% [markdown]
# ## Does the organisation Experience staff turnover?
# ### Number of Employees likely to Exit the organisation

# %%
df_surveymonkey['I see myself working at the Agriculture and Food Authority in the next 2 years ?']
attrition_is_yes= df_surveymonkey[df_surveymonkey['I see myself working at the Agriculture and Food Authority in the next 2 years ?']== "No"]
attrition_is_no= df_surveymonkey[df_surveymonkey['I see myself working at the Agriculture and Food Authority in the next 2 years ?']== "Yes"]

# %%
#define data
#https://www.statology.org/seaborn-pie-chart/
yes=len(attrition_is_yes)
no=len(attrition_is_no)
data = [yes,no]
labels = ['Attrition Yes', 'Attrition No']
#define Seaborn color palette to use
colors = sns.color_palette('bright')[0:5]
#create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# ### From the analysis, 20% of the total sample are likely to exit the organisation in the next 3 years

# %%
attrition_is_yes = attrition_is_yes.rename(columns={'I see myself working at the Agriculture and Food Authority in the next 2 years ?': 'Attrition','The organization has a structure with clear reporting lines ?':'clear_reporting_line','The organization’s culture promotes divergent views and opinions and allow room for discussion?':'democracy','The organization has an effective communication policy ?':'communication_policy','I work well with my supervisor?':'supervisor-relationship'})
attrition_is_yes = attrition_is_yes[['Attrition','clear_reporting_line','democracy','communication_policy','supervisor-relationship']]

# %% [markdown]
# ### a) 46% of the employees likely to exit the organisation,say the organisation did not offer them training training opportunities

# %%
clear_reporting_line=attrition_is_yes[attrition_is_yes['clear_reporting_line']== "Yes"]
clear_reporting_line_no=attrition_is_yes[attrition_is_yes['clear_reporting_line']== "No"]
yes=len(clear_reporting_line)
no=len(clear_reporting_line_no)
data = [yes,no]
labels = ['Clear reporting line', 'No clear Reporting line']
#define Seaborn color palette to use
colors = sns.color_palette('bright')[0:5]
#create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %%
democracy=attrition_is_yes[attrition_is_yes['democracy']== "Yes"]

democracy_no=attrition_is_yes[attrition_is_yes['democracy']== "No"]

yes=len(democracy)
no=len(democracy_no)
data = [yes,no]
labels = ['Democracy', 'No Democracy']
#define Seaborn color palette to use
colors = sns.color_palette('bright')[0:5]
#create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %%
communication_policy=attrition_is_yes[attrition_is_yes['communication_policy']== "Yes"]

communication_policy_no=attrition_is_yes[attrition_is_yes['communication_policy']== "No"]

yes=len(communication_policy)
no=len(communication_policy_no)
data = [yes,no]
labels = ['Communication Policy', 'No Communication Policy']
#define Seaborn color palette to use
colors = sns.color_palette('bright')[0:5]
#create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %%
supervisor_relationship=attrition_is_yes[attrition_is_yes['supervisor-relationship']== "Yes"]

supervisor_relationship_no=attrition_is_yes[attrition_is_yes['supervisor-relationship']== "No"]

yes=len(supervisor_relationship)
no=len(supervisor_relationship_no)
data = [yes,no]
labels = ['Good Supervisor relationship', 'Poor Supervisor relationship']
#define Seaborn color palette to use
colors = sns.color_palette('bright')[0:5]
#create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()
